-- %% [markdown]
-- ####  Unity Catalog Setup
-- #####  RUN ONCE PER ENVIRONMENT
-- #####  Environment: DEV

-- %%
SHOW STORAGE CREDENTIALS;

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dev_bronze_ext_location_UC
URL 'abfss://bronze@ecommerceanalyticsdevgqb.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dev-ecomanalytics-uc-ext-credentials`)
COMMENT 'Bronze layer raw data';

-- %% [markdown]
-- ##### Create External Locations for CheckPoints

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dev_checkpoints_ext_location_UC
URL 'abfss://checkpoints@ecommerceanalyticsdevgqb.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dev-ecomanalytics-uc-ext-credentials`)
COMMENT 'Streaming checkpoints';

-- %%
-- Verify
SHOW EXTERNAL LOCATIONS;

-- %% [markdown]
-- ##### confirm location access

-- %%
LIST 'abfss://bronze@ecommerceanalyticsdevgqb.dfs.core.windows.net/';

-- %%
CREATE CATALOG IF NOT EXISTS ecommerce_analytics_dev
COMMENT 'E-commerce analytics platform - DEV environment';

-- Verify
SHOW CATALOGS;

-- %%
USE CATALOG ecommerce_analytics_dev;

CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Raw data - External tables pointing to ADLS bronze container';

CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Cleaned and transformed data - Managed tables';

CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Business aggregations - Managed tables';

CREATE SCHEMA IF NOT EXISTS staging
COMMENT 'Temporary tables for incremental loads';

-- Verify
SHOW SCHEMAS;

-- %%
USE ecommerce_analytics_dev.bronze;

-- %%
%python
df = spark.read.option("header", "true").csv("abfss://bronze@ecommerceanalyticsdevgqb.dfs.core.windows.net/ROA30.20260116T220151.csv")
display(df)
